# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

satScores = pd.read_csv('../assets/sat_scores.csv')
satScores.columns = ['State', 'Rate', 'Verbal', 'Math', ]

# %%
print satScores.head()
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516

# %% [markdown]
# The data shows a state value with a corrisponding paticiaption rate, along with a verbal and math score.

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# The data does appear complete with no null values or incorrect data types. There doesnt appear to be any issues with the data.

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %%
satList = np.array(satScores)

mydict = {}
for row in satList:
    key = row[0]
    mydict[key] = list(row[1:])
    
print mydict
# Out:
# {'WA': [53, 527, 527], 'DE': [67, 501, 499], 'DC': [56, 482, 474], 'WI': [6, 584, 596], 'WV': [18, 527, 512], 'HI': [52, 485, 515], 'FL': [54, 498, 499], 'WY': [11, 547, 545], 'NH': [72, 520, 516], 'NJ': [81, 499, 513], 'NM': [13, 551, 542], 'TX': [53, 493, 499], 'LA': [7, 564, 562], 'NC': [65, 493, 499], 'ND': [4, 592, 599], 'NE': [8, 562, 568], 'TN': [13, 562, 553], 'NY': [77, 495, 505], 'PA': [71, 500, 499], 'RI': [71, 501, 499], 'NV': [33, 509, 515], 'VA': [68, 510, 501], 'CO': [31, 539, 542], 'AK': [51, 514, 510], 'AL': [9, 559, 554], 'AR': [6, 562, 550], 'VT': [69, 511, 506], 'IL': [12, 576, 589], 'GA': [63, 491, 489], 'IN': [60, 499, 501], 'IA': [5, 593, 603], 'OK': [8, 567, 561], 'AZ': [34, 523, 525], 'CA': [51, 498, 517], 'ID': [17, 543, 542], 'CT': [82, 509, 510], 'ME': [69, 506, 500], 'MD': [65, 508, 510], 'All': [45, 506, 514], 'MA': [79, 511, 515], 'OH': [26, 534, 439], 'UT': [5, 575, 570], 'MO': [8, 577, 577], 'MN': [9, 580, 589], 'MI': [11, 561, 572], 'KS': [9, 577, 58
# ...

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
satList = np.array(satScores)
satScores.columns = ['State', 'Rate', 'Verbal', 'Math', ]

# %% [markdown]
# ##### 5. Print the data

# %%
print satList
# Out:
# [['CT' 82 509 510]
#  ['NJ' 81 499 513]
#  ['MA' 79 511 515]
#  ['NY' 77 495 505]
#  ['NH' 72 520 516]
#  ['RI' 71 501 499]
#  ['PA' 71 500 499]
#  ['VT' 69 511 506]
#  ['ME' 69 506 500]
#  ['VA' 68 510 501]
#  ['DE' 67 501 499]
#  ['MD' 65 508 510]
#  ['NC' 65 493 499]
#  ['GA' 63 491 489]
#  ['IN' 60 499 501]
#  ['SC' 57 486 488]
#  ['DC' 56 482 474]
#  ['OR' 55 526 526]
#  ['FL' 54 498 499]
#  ['WA' 53 527 527]
#  ['TX' 53 493 499]
#  ['HI' 52 485 515]
#  ['AK' 51 514 510]
#  ['CA' 51 498 517]
#  ['AZ' 34 523 525]
#  ['NV' 33 509 515]
#  ['CO' 31 539 542]
#  ['OH' 26 534 439]
#  ['MT' 23 539 539]
#  ['WV' 18 527 512]
#  ['ID' 17 543 542]
#  ['TN' 13 562 553]
#  ['NM' 13 551 542]
#  ['IL' 12 576 589]
#  ['KY' 12 550 550]
#  ['WY' 11 547 545]
#  ['MI' 11 561 572]
#  ['MN' 9 580 589]
#  ['KS' 9 577 580]
#  ['AL' 9 559 554]
#  ['NE' 8 562 568]
#  ['OK' 8 567 561]
#  ['MO' 8 577 577]
#  ['LA' 7 564 562]
#  ['WI' 6 584 596]
#  ['AR' 6 562 550]
#  ['UT' 5 575 570]
#  ['IA' 5 593 603]
# ...

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
list(satScores.columns.values)
# Out:
# ['State', 'Rate', 'Verbal', 'Math']

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
states = [satScores.State]
print states
# Out:
# [0      CT
# 1      NJ
# 2      MA
# 3      NY
# 4      NH
# 5      RI
# 6      PA
# 7      VT
# 8      ME
# 9      VA
# 10     DE
# 11     MD
# 12     NC
# 13     GA
# 14     IN
# 15     SC
# 16     DC
# 17     OR
# 18     FL
# 19     WA
# 20     TX
# 21     HI
# 22     AK
# 23     CA
# 24     AZ
# 25     NV
# 26     CO
# 27     OH
# 28     MT
# 29     WV
# 30     ID
# 31     TN
# 32     NM
# 33     IL
# 34     KY
# 35     WY
# 36     MI
# 37     MN
# 38     KS
# 39     AL
# 40     NE
# 41     OK
# 42     MO
# 43     LA
# 44     WI
# 45     AR
# 46     UT
# 47     IA
# 48     SD
# 49     ND
# 50     MS
# 51    All
# Name: State, dtype: object]

# %% [markdown]
# ##### 8. Print the types of each column

# %%
print satScores.State.dtype
print satScores.Rate.dtype
print satScores.Math.dtype
print satScores.Verbal.dtype
# Out:
# object
# int64
# int64
# int64

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
statScores = satScores.State.values.astype(str)

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
print mydict
# Out:
# {'WA': [53, 527, 527], 'DE': [67, 501, 499], 'DC': [56, 482, 474], 'WI': [6, 584, 596], 'WV': [18, 527, 512], 'HI': [52, 485, 515], 'FL': [54, 498, 499], 'WY': [11, 547, 545], 'NH': [72, 520, 516], 'NJ': [81, 499, 513], 'NM': [13, 551, 542], 'TX': [53, 493, 499], 'LA': [7, 564, 562], 'NC': [65, 493, 499], 'ND': [4, 592, 599], 'NE': [8, 562, 568], 'TN': [13, 562, 553], 'NY': [77, 495, 505], 'PA': [71, 500, 499], 'RI': [71, 501, 499], 'NV': [33, 509, 515], 'VA': [68, 510, 501], 'CO': [31, 539, 542], 'AK': [51, 514, 510], 'AL': [9, 559, 554], 'AR': [6, 562, 550], 'VT': [69, 511, 506], 'IL': [12, 576, 589], 'GA': [63, 491, 489], 'IN': [60, 499, 501], 'IA': [5, 593, 603], 'OK': [8, 567, 561], 'AZ': [34, 523, 525], 'CA': [51, 498, 517], 'ID': [17, 543, 542], 'CT': [82, 509, 510], 'ME': [69, 506, 500], 'MD': [65, 508, 510], 'All': [45, 506, 514], 'MA': [79, 511, 515], 'OH': [26, 534, 439], 'UT': [5, 575, 570], 'MO': [8, 577, 577], 'MN': [9, 580, 589], 'MI': [11, 561, 572], 'KS': [9, 577, 58
# ...

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
print "Rate"
print 'Min ', min(satScores['Rate'])
print 'Max ', max(satScores['Rate']) 
print '\n', "Verbal" 
print 'Min ', min(satScores['Verbal'])
print 'Max ', max(satScores['Verbal'])
print '\n'  "Math"
print 'Min ', min(satScores['Math'])
print 'Max ', max(satScores['Math'])
# Out:
# Rate
# Min  4
# Max  82
#
# Verbal
# Min  482
# Max  593
#
# Math
# Min  439
# Max  603

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
def stddev(lst):
    mn = np.mean(lst)
    varience = sum([(e-mn)**2 for e in lst]) / len(lst)
    return np.sqrt(varience)

print stddev(satScores['Rate'])
print stddev(satScores['Verbal'])
print stddev(satScores['Math'])
# Out:
# 27.0379964945
# 32.9150949616
# 35.6669961643

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
satRate = satScores.Rate
plt.hist(satrate)
plt.show()

# %% [markdown]
# ##### 15. Plot the Math distribution

# %%
satMath = np.transpose(satScores.Math)

plt.hist(satMath)
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %%
satVerble = satScores.Verbal
plt.hist(satVerbal)
plt.show()

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %% [markdown]
# When making a statisical analisys, we most often assume the the data is normally distributed. Normal is that 68% of the data is one standard deviation away from the mean.

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %% [markdown]
# The data does not appear to be normally distributed

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
plt.scatter(satRate, satMath, alpha = 0.5)
plt.scatter(satRate, satVerble , alpha = 0.5)
plt.show()

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %% [markdown]
# The lower rates have a higher score. This could be due to higher preperation.

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %%
plt.boxplot(satRate)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11bb0d910>],
#  'caps': [<matplotlib.lines.Line2D at 0x11be82790>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11be85a90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11be85450>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11bb0da50>,
#   <matplotlib.lines.Line2D at 0x11be82150>]}

# %%
plt.boxplot(satVerbal)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11c030a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x11c030c10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11b299a10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11bab8610>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11c0306d0>,
#   <matplotlib.lines.Line2D at 0x11c030150>]}

# %%
plt.boxplot(satMath)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x11baa4e50>],
#  'caps': [<matplotlib.lines.Line2D at 0x11b160cd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11b141fd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11b141990>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11baa4f90>,
#   <matplotlib.lines.Line2D at 0x11b160690>]}

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %%
from IPython.display import Image
Image("../HeatMap.png")
